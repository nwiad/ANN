# %% [markdown]
# 1. 挂载 Google Drive 目录

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# 2. 进入 `HW3/codes` 目录下

# %%
import os
os.chdir("/content/drive/My Drive/HW3/codes")

# %% [markdown]
# 3. 查看目录下文件

# %%
# !ls
# Out:
# config.json	  data	   model_tfmr.py  __pycache__	   tokenizer	 train_test
# configuration.py  main.py  pretrained	  run_colab.ipynb  tokenizer.py  wandb

# %%
# !pip install wandb
# !pip install nltk==3.5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434680 sha256=28888408a5f36305c3dec523149db2e10c2f0e9fc205a900b1ca7480e308d76a
#   Stored in directory: /root/.cache/pip/wheels/35/ab/82/f9667f6f884d272670a15382599a9c753a1dfdc83f7412e37d
# Successfully built nltk
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# ...

# %% [markdown]
# 4. 运行作业程序

# %%
# !python3 main.py --name="Tfmr-scratch"
# Out:
# Namespace(name='Tfmr-scratch', model_config='./config.json', tokenizer_dir='./tokenizer', num_epochs=20, cpu_count=20, batch_size=32, learning_rate=0.0001, test=None, data_dir='./data', train_dir='./train_test', pretrain_dir=None, maxlen=35, decode_strategy='random', temperature=1, top_p=1.0)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /content/drive/MyDrive/HW3/codes/wandb/run-20231111_105652-bsni4d22
# ...

# %%
# !python3 main.py --name="Tfmr-finetune" --model_config=pretrained/model_3_layers/config.json --pretrain_dir=pretrained/model_3_layers
# Out:
# Namespace(name='Tfmr-finetune', model_config='pretrained/model_3_layers/config.json', tokenizer_dir='./tokenizer', num_epochs=20, cpu_count=20, batch_size=32, learning_rate=0.0001, test=None, data_dir='./data', train_dir='./train_test', pretrain_dir='pretrained/model_3_layers', maxlen=35, decode_strategy='random', temperature=1, top_p=1.0)
# wandb: Currently logged in as: dython (byd_). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /content/drive/MyDrive/HW3/codes/wandb/run-20231111_110826-uuim6ari
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Tfmr-finetune_random_1_1.0
# wandb: ⭐️ View project at https://wandb.ai/byd_/transformer
# wandb: 🚀 View run at https://wandb.ai/byd_/transformer/runs/uuim6ari
# Tokenizer PAD ID: 50256
# Loading Data ...
# Loading model from pretrained/model_3_layers/pretrained_ckpt.bin
# ...

# %%
# !python3 main.py --test="Tfmr-scratch"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 3 A man guy holding a basket is looking at a sheep .
# 4 A bus is stopped at a stop in a crowded intersection .
# 5 A park bench sits in the middle of a park .
# 6 A sign sitting in the middle of a city street .
# 7 A passenger sitting plane in a parking lot near a beach .
# 8 A mother sheep and her baby giraffe standing together in a grassy area .
# 9 A red and commercial airliner sitting docked at a airport .
# 10 A woman wearing a glasses sits on a park bench .
# 11 A man sits on a bench near a tree and grassy area .
# 12 A red couple gallery of benches sitting in the middle of an still .
# 13 A river with a traffic light and a streetama sidewalk .
# 14 A young man sitting on a bench in the snow .
# 15 A herd of sheep standing in grass covered in snow .
# 16 A woman and two ladies are working in this photo .
# 17 A red traffic light sitting next to a metal pole .
# 18 A man sitting on a bench near a bird surface .
# ...

# %%
# !python3 main.py --test="Tfmr-finetune"
